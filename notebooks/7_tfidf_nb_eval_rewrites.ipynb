# %%
# imports
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_predict, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay

# %%
# data

#file_path = r"C:\Users\mrang\Downloads\master_0_dataset.csv"
file_path = "../data/master_0_dataset.csv"
data = pd.read_csv(file_path)
data.head()
# Out:
#    id                                               text  label  \
# 0   0   Have you ever pondered the evolution of indiv...     ai
# 1   1   Dear Reader,\n\nLet us embark on an explorati...     ai
# 2   2  London: Crude prices fell Thursday awaiting th...  human
# 3   3  ISLAMABAD: Pakistan captain Inamul Haq is opti...  human
# 4   4   Title: A Sunny Day Revival at Culver's After ...     ai
#
#   generation_type        source      source_id
# 0       zero_shot      ai_essay    ai_essay_21
# 1       zero_shot      ai_essay     ai_essay_9
# 2           human  articles.csv   articles_324
# 3           human  articles.csv  articles_1592
# 4       zero_shot     ai_review   ai_review_12

# %% [markdown]
# ## Data Cleaning

# %%
# normalize text/labels
data['text'] = data['text'].astype(str)
data['label'] = data['label'].str.lower().str.strip()

# numberic labels
label_map = {'human': 0, 'ai': 1}
data['label_num'] = data['label'].map(label_map)

# drop bad rows
data = data.dropna(subset=["text", "label_num"])
data = data[data["text"].str.strip() != ""]

# %%
# features + labels
X_text = data['text']
y = data['label_num']

# %%
# train/test split

X_train, X_test, y_train, y_test = train_test_split(
    X_text,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %% [markdown]
# ## Initial Fit

# %%
# tf-idf features pipeline

pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(
        stop_words='english',
        max_features=5000
    )),
    ("nb", MultinomialNB()) # naive bayes classifier
])

# %%
# fit on train + eval on test

pipeline.fit(X_train, y_train)

y_test_pred = pipeline.predict(X_test)
y_test_proba = pipeline.predict_proba(X_test)[:, 1]

print("Test Accuracy:", accuracy_score(y_test, y_test_pred))

print("\nTest Classification Report:")
print(classification_report(y_test, y_test_pred, target_names=["human", "ai"]))
# Out:
# Test Accuracy: 0.9791666666666666
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#        human       0.99      0.97      0.98       120
#           ai       0.97      0.99      0.98       120
#
#     accuracy                           0.98       240
#    macro avg       0.98      0.98      0.98       240
# weighted avg       0.98      0.98      0.98       240

# %%
# confusion matrix

cm = confusion_matrix(y_test, y_test_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["human", "ai"]
)

disp.plot()
plt.title("Confusion Matrix")
plt.show()

# %%
# roc auc

auc = roc_auc_score(y_test, y_test_proba)
print("Test ROC AUC:", auc)

RocCurveDisplay.from_predictions(
    y_test,
    y_test_proba,
    name="TF-IDF + Naive Bayes"
)

plt.title("ROC Curve")
plt.show()
# Out:
# Test ROC AUC: 0.9993055555555556

# %% [markdown]
# ## 10-Fold CV

# %%
# stratified 10 fold cross validation 
cv = StratifiedKFold(
    n_splits=10,
    shuffle=True,
    random_state=42
)

accuracy_scores = cross_val_score(
    pipeline,
    X_text,
    y,
    cv=cv,
    scoring='accuracy'
)

print("Accuracy scores for each fold:")
print(accuracy_scores)

print("\nMean accuracy:", accuracy_scores.mean())
# Out:
# Accuracy scores for each fold:
# [0.99166667 0.99166667 1.         0.99166667 0.975      0.975
#  0.98333333 0.975      0.98333333 0.99166667]
#
# Mean accuracy: 0.9858333333333332

# %%
# predictions + report
y_pred = cross_val_predict(
    pipeline,
    X_text,
    y,
    cv=cv
)

print("\nClassification Report:")
print(classification_report(y, y_pred, target_names=['human', 'ai']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        human       0.99      0.98      0.99       600
#           ai       0.98      0.99      0.99       600
#
#     accuracy                           0.99      1200
#    macro avg       0.99      0.99      0.99      1200
# weighted avg       0.99      0.99      0.99      1200

# %%
print("\nConfusion Matrix (Stratified):")
# confusion matrix

cm = confusion_matrix(y, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["human", "ai"]
)

disp.plot()
plt.title("Confusion Matrix (Stratified)")
plt.show()
# Out:
# Confusion Matrix (Stratified):

# %%
# roc auc

auc = roc_auc_score(y_test, y_test_proba)
print("ROC AUC (Stratified):", auc)

RocCurveDisplay.from_predictions(
    y_test,
    y_test_proba,
    name="TF-IDF + Naive Bayes"
)

plt.title("ROC Curve (Stratified)")
plt.show()
# Out:
# ROC AUC (Stratified): 0.9993055555555556
